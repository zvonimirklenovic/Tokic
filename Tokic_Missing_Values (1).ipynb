# %% [markdown]
# ## Suočavanje s nedostajućim vrijednostima
# ### učitavanje potrebnih paketa

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### učitavanje stvorene CSV datoteke sa standardnim i nestandardnim nedostajućim vrijednostima

# %%
df = pd.read_csv("dijelovi data.csv")
df
# Out:
#            PID  broj artikla       Ime artikla dostupnost komada u skladistu  \
# 0  100001000.0         104.0       GUMA ZIMSKE          Y                  3
# 1  100002000.0         197.0       GUME LJETNE          N                  3
# 2  100003000.0           NaN             FELGE          N                NaN
# 3  100004000.0         201.0   BRISACI PREDNJI         12                  1
# 4          NaN         203.0  BRISACI STRAZNJI          Y                  3
# 5  100006000.0         207.0           BRISACI          Y                NaN
# 6  100007000.0           NaN     Zracni FILTER        NaN                  2
# 7  100008000.0         213.0    KLINASTI REMEN          Y                  1
# 8  100009000.0         215.0          ANTIFRIZ          Y                 na
#
#   Unnamed: 5 cijena
# 0          4   1000
# 1        4.5     --
# 2          2    850
# 3        NaN    700
# 4          2   1600
# 5          1    800
# 6      HURLE    950
# 7          5    NaN
# 8          3   1800

# %%
# Looking at the 'broj artikla' column
print(df['broj artikla'])
# Out:
# 0    104.0
# 1    197.0
# 2      NaN
# 3    201.0
# 4    203.0
# 5    207.0
# 6      NaN
# 7    213.0
# 8    215.0
# Name: broj artikla, dtype: float64

# %%
print(df['broj artikla'].isnull())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: broj artikla, dtype: bool

# %%
# Looking at the komada u skladistu column
print(df['komada u skladistu'])
# Out:
# 0      3
# 1      3
# 2    NaN
# 3      1
# 4      3
# 5    NaN
# 6      2
# 7      1
# 8     na
# Name: komada u skladistu, dtype: object

# %%
print(df['komada u skladistu'].isnull())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# Name: komada u skladistu, dtype: bool

# %% [markdown]
# #### standardne nedostaju'e vrijednosti prikazane su kao NaN, a u našem slučaju postoje i ne standardne vrijednosti  prikazane kao "na", pa ih dodajemo na popis nedostajućih vrijednosti

# %%
# Making a list of missing value types
missing_values = ["na"]
df = pd.read_csv("dijelovi data.csv", na_values = missing_values)

# %%
# Looking at the komada u skladistu column
print(df['komada u skladistu'])
# Out:
# 0    3.0
# 1    3.0
# 2    NaN
# 3    1.0
# 4    3.0
# 5    NaN
# 6    2.0
# 7    1.0
# 8    NaN
# Name: komada u skladistu, dtype: float64

# %%
df
# Out:
#            PID  broj artikla       Ime artikla dostupnost  komada u skladistu  \
# 0  100001000.0         104.0       GUMA ZIMSKE          Y                 3.0
# 1  100002000.0         197.0       GUME LJETNE          N                 3.0
# 2  100003000.0           NaN             FELGE          N                 NaN
# 3  100004000.0         201.0   BRISACI PREDNJI         12                 1.0
# 4          NaN         203.0  BRISACI STRAZNJI          Y                 3.0
# 5  100006000.0         207.0           BRISACI          Y                 NaN
# 6  100007000.0           NaN     Zracni FILTER        NaN                 2.0
# 7  100008000.0         213.0    KLINASTI REMEN          Y                 1.0
# 8  100009000.0         215.0          ANTIFRIZ          Y                 NaN
#
#   Unnamed: 5 cijena
# 0          4   1000
# 1        4.5     --
# 2          2    850
# 3        NaN    700
# 4          2   1600
# 5          1    800
# 6      HURLE    950
# 7          5    NaN
# 8          3   1800

# %% [markdown]
# #### Ovaj je primjer malo zamršeniji, numerička vrijednost pojavljuje se u stupcu kategorijskih vrijednosti, ali nije prepoznata kao nedostajuća vrijednost

# %%
# Looking at the dostupnost column
print(df['dostupnost'])
# Out:
# 0      Y
# 1      N
# 2      N
# 3     12
# 4      Y
# 5      Y
# 6    NaN
# 7      Y
# 8      Y
# Name: dostupnost, dtype: object

# %%
print(df['dostupnost'].isnull())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: dostupnost, dtype: bool

# %% [markdown]
# #### sljedeća funkcija proći će kroz stupac i klasificirati numeričku vrijednost kao nedostajuću vrijednost

# %%
# Detecting numbers 
cnt=0
for row in df['dostupnost']:
    try:
        int(row)
        df.loc[cnt, 'dostupnost']=np.nan
    except ValueError:
        pass
    cnt+=1

# %%
df
# Out:
#            PID  broj artikla       Ime artikla dostupnost  komada u skladistu  \
# 0  100001000.0         104.0       GUMA ZIMSKE          Y                 3.0
# 1  100002000.0         197.0       GUME LJETNE          N                 3.0
# 2  100003000.0           NaN             FELGE          N                 NaN
# 3  100004000.0         201.0   BRISACI PREDNJI        NaN                 1.0
# 4          NaN         203.0  BRISACI STRAZNJI          Y                 3.0
# 5  100006000.0         207.0           BRISACI          Y                 NaN
# 6  100007000.0           NaN     Zracni FILTER        NaN                 2.0
# 7  100008000.0         213.0    KLINASTI REMEN          Y                 1.0
# 8  100009000.0         215.0          ANTIFRIZ          Y                 NaN
#
#   Unnamed: 5 cijena
# 0          4   1000
# 1        4.5     --
# 2          2    850
# 3        NaN    700
# 4          2   1600
# 5          1    800
# 6      HURLE    950
# 7          5    NaN
# 8          3   1800

# %% [markdown]
# #### različiti primjeri brojanja i prikazivanja nedostajućih vrijednosti u podatkovnom okviru

# %%
# Total missing values for each feature
print(df.isnull().sum())
# Out:
# PID                   1
# broj artikla          2
# Ime artikla           0
# dostupnost            2
# komada u skladistu    3
# Unnamed: 5            1
# cijena                1
# dtype: int64

# %%
# Any missing values?
print(df.isnull().values.any())
# Out:
# True

# %%
# Total number of missing values
print(df.isnull().sum().sum())
# Out:
# 10

# %% [markdown]
# #### primjer zamjene svih nedostajućih vrijednosti u stupcu istom novom vrijednošću

# %%
# Replace missing values with a number
df['broj artikla'].fillna(125, inplace=True)

# %%
df
# Out:
#            PID  broj artikla       Ime artikla dostupnost  komada u skladistu  \
# 0  100001000.0         104.0       GUMA ZIMSKE          Y                 3.0
# 1  100002000.0         197.0       GUME LJETNE          N                 3.0
# 2  100003000.0         125.0             FELGE          N                 NaN
# 3  100004000.0         201.0   BRISACI PREDNJI        NaN                 1.0
# 4          NaN         203.0  BRISACI STRAZNJI          Y                 3.0
# 5  100006000.0         207.0           BRISACI          Y                 NaN
# 6  100007000.0         125.0     Zracni FILTER        NaN                 2.0
# 7  100008000.0         213.0    KLINASTI REMEN          Y                 1.0
# 8  100009000.0         215.0          ANTIFRIZ          Y                 NaN
#
#   Unnamed: 5 cijena
# 0          4   1000
# 1        4.5     --
# 2          2    850
# 3        NaN    700
# 4          2   1600
# 5          1    800
# 6      HURLE    950
# 7          5    NaN
# 8          3   1800

# %% [markdown]
# #### promjena naziva stupca

# %%
df.rename(columns={'Unnamed: 5':'Rejting'}, inplace=True)
df
# Out:
#            PID  broj artikla       Ime artikla dostupnost  komada u skladistu  \
# 0  100001000.0         104.0       GUMA ZIMSKE          Y                 3.0
# 1  100002000.0         197.0       GUME LJETNE          N                 3.0
# 2  100003000.0         125.0             FELGE          N                 NaN
# 3  100004000.0         201.0   BRISACI PREDNJI        NaN                 1.0
# 4          NaN         203.0  BRISACI STRAZNJI          Y                 3.0
# 5  100006000.0         207.0           BRISACI          Y                 NaN
# 6  100007000.0         125.0     Zracni FILTER        NaN                 2.0
# 7  100008000.0         213.0    KLINASTI REMEN          Y                 1.0
# 8  100009000.0         215.0          ANTIFRIZ          Y                 NaN
#
#   Rejting cijena
# 0       4   1000
# 1     4.5     --
# 2       2    850
# 3     NaN    700
# 4       2   1600
# 5       1    800
# 6   HURLE    950
# 7       5    NaN
# 8       3   1800

# %% [markdown]
# #### zamjena točno pronađenih nedostajućih ili netočnih vrijednosti novima

# %%
df.loc[4,'PID'] = 100005000.0
df.loc[6,'Rejting'] = 4
df.loc[1,'cijena'] = 1000
df.loc[7,'cijena'] = 980

# %%
df
# Out:
#            PID  broj artikla       Ime artikla dostupnost  komada u skladistu  \
# 0  100001000.0         104.0       GUMA ZIMSKE          Y                 3.0
# 1  100002000.0         197.0       GUME LJETNE          N                 3.0
# 2  100003000.0         125.0             FELGE          N                 NaN
# 3  100004000.0         201.0   BRISACI PREDNJI        NaN                 1.0
# 4  100005000.0         203.0  BRISACI STRAZNJI          Y                 3.0
# 5  100006000.0         207.0           BRISACI          Y                 NaN
# 6  100007000.0         125.0     Zracni FILTER        NaN                 2.0
# 7  100008000.0         213.0    KLINASTI REMEN          Y                 1.0
# 8  100009000.0         215.0          ANTIFRIZ          Y                 NaN
#
#   Rejting cijena
# 0       4   1000
# 1     4.5   1000
# 2       2    850
# 3     NaN    700
# 4       2   1600
# 5       1    800
# 6       4    950
# 7       5    980
# 8       3   1800

# %% [markdown]
# #### zamijenite nedostajuće vrijednosti koristeći srednju vrijednost median

# %%
# Replace using median 
median = df['komada u skladistu'].median()
df['komada u skladistu'].fillna(median, inplace=True)

# %%
df
# Out:
#            PID  broj artikla       Ime artikla dostupnost  komada u skladistu  \
# 0  100001000.0         104.0       GUMA ZIMSKE          Y                 3.0
# 1  100002000.0         197.0       GUME LJETNE          N                 3.0
# 2  100003000.0         125.0             FELGE          N                 2.5
# 3  100004000.0         201.0   BRISACI PREDNJI        NaN                 1.0
# 4  100005000.0         203.0  BRISACI STRAZNJI          Y                 3.0
# 5  100006000.0         207.0           BRISACI          Y                 2.5
# 6  100007000.0         125.0     Zracni FILTER        NaN                 2.0
# 7  100008000.0         213.0    KLINASTI REMEN          Y                 1.0
# 8  100009000.0         215.0          ANTIFRIZ          Y                 2.5
#
#   Rejting cijena
# 0       4   1000
# 1     4.5   1000
# 2       2    850
# 3     NaN    700
# 4       2   1600
# 5       1    800
# 6       4    950
# 7       5    980
# 8       3   1800

# %% [markdown]
# #### izračunavanje prosječne ocjene i zamjena nedostajućih vrijednosti s prosjekom

# %%
avg_rejting = df['Rejting'].astype("float").mean(axis=0)
print("Prosjecan Rejting:", avg_rejting)
# Out:
# Prosjecan Rejting: 3.1875

# %%
df['Rejting'].replace(np.nan, avg_rejting, inplace = True)

# %%
df
# Out:
#            PID  broj artikla       Ime artikla dostupnost  komada u skladistu  \
# 0  100001000.0         104.0       GUMA ZIMSKE          Y                 3.0
# 1  100002000.0         197.0       GUME LJETNE          N                 3.0
# 2  100003000.0         125.0             FELGE          N                 2.5
# 3  100004000.0         201.0   BRISACI PREDNJI        NaN                 1.0
# 4  100005000.0         203.0  BRISACI STRAZNJI          Y                 3.0
# 5  100006000.0         207.0           BRISACI          Y                 2.5
# 6  100007000.0         125.0     Zracni FILTER        NaN                 2.0
# 7  100008000.0         213.0    KLINASTI REMEN          Y                 1.0
# 8  100009000.0         215.0          ANTIFRIZ          Y                 2.5
#
#   Rejting cijena
# 0       4   1000
# 1     4.5   1000
# 2       2    850
# 3  3.1875    700
# 4       2   1600
# 5       1    800
# 6       4    950
# 7       5    980
# 8       3   1800

# %%
#### changing column names to upper case

# %%
df.columns = map(lambda x: str(x).upper(), df.columns)

# %%
df
# Out:
#            PID  BROJ ARTIKLA       IME ARTIKLA DOSTUPNOST  KOMADA U SKLADISTU  \
# 0  100001000.0         104.0       GUMA ZIMSKE          Y                 3.0
# 1  100002000.0         197.0       GUME LJETNE          N                 3.0
# 2  100003000.0         125.0             FELGE          N                 2.5
# 3  100004000.0         201.0   BRISACI PREDNJI        NaN                 1.0
# 4  100005000.0         203.0  BRISACI STRAZNJI          Y                 3.0
# 5  100006000.0         207.0           BRISACI          Y                 2.5
# 6  100007000.0         125.0     Zracni FILTER        NaN                 2.0
# 7  100008000.0         213.0    KLINASTI REMEN          Y                 1.0
# 8  100009000.0         215.0          ANTIFRIZ          Y                 2.5
#
#   REJTING CIJENA
# 0       4   1000
# 1     4.5   1000
# 2       2    850
# 3  3.1875    700
# 4       2   1600
# 5       1    800
# 6       4    950
# 7       5    980
# 8       3   1800
